# %%
import pandas as pd
perf = pd.read_pickle('output.pickle')
perf.head()
# Out:
#                            algo_volatility  algorithm_period_return     alpha  \
# 2014-01-02 21:00:00+00:00              NaN                 0.000000       NaN
# 2014-01-03 21:00:00+00:00         0.004469                -0.000398 -0.097320
# 2014-01-06 21:00:00+00:00         0.036950                -0.004612 -0.424854
# 2014-01-07 21:00:00+00:00         0.083760                -0.015942 -0.722139
# 2014-01-08 21:00:00+00:00         0.182891                 0.003394  0.067240
#
#                            benchmark_period_return  benchmark_volatility  \
# 2014-01-02 21:00:00+00:00                -0.009584                   NaN
# 2014-01-03 21:00:00+00:00                -0.009773              0.105426
# 2014-01-06 21:00:00+00:00                -0.012616              0.076805
# 2014-01-07 21:00:00+00:00                -0.006552              0.103395
# 2014-01-08 21:00:00+00:00                -0.006335              0.090494
#
#                                beta  capital_used   ending_cash  \
# 2014-01-02 21:00:00+00:00       NaN  0.000000e+00  1.000000e+07
# 2014-01-03 21:00:00+00:00 -0.042387 -1.410551e+06  8.589449e+06
# 2014-01-06 21:00:00+00:00 -0.155288  4.526255e+06  1.311570e+07
# 2014-01-07 21:00:00+00:00 -0.657977 -1.299759e+06  1.181595e+07
# 2014-01-08 21:00:00+00:00 -0.375779 -2.789682e+05  1.153698e+07
#
#                            ending_exposure  ending_value  \
# 2014-01-02 21:00:00+00:00             0.00          0.00
# 2014-01-03 21:00:00+00:00       1406569.51    1406569.51
# 2014-01-06 21:00:00+00:00      -3161827.36   -3161827.36
# 2014-01-07 21:00:00+00:00      -1975367.56   -1975367.56
# 2014-01-08 21:00:00+00:00      -1503033.28   -1503033.28
#
#                                    ...            short_exposure  short_value  \
# 2014-01-02 21:00:00+00:00          ...                      0.00         0.00
# 2014-01-03 21:00:00+00:00          ...               -3073843.52  -3073843.52
# 2014-01-06 21:00:00+00:00          ...               -6998074.84  -6998074.84
# 2014-01-07 21:00:00+00:00          ...               -6757227.57  -6757227.57
# 2014-01-08 21:00:00+00:00          ...               -6049368.64  -6049368.64
#
#                            shorts_count    sortino  starting_cash  \
# 2014-01-02 21:00:00+00:00             0        NaN   1.000000e+07
# 2014-01-03 21:00:00+00:00             7 -11.224972   1.000000e+07
# 2014-01-06 21:00:00+00:00             6  -9.986194   8.589449e+06
# 2014-01-07 21:00:00+00:00             7 -10.454615   1.311570e+07
# 2014-01-08 21:00:00+00:00             6   2.135730   1.181595e+07
#
#                            starting_exposure  starting_value  trading_days  \
# 2014-01-02 21:00:00+00:00               0.00            0.00             1
# 2014-01-03 21:00:00+00:00               0.00            0.00             2
# 2014-01-06 21:00:00+00:00         1406569.51      1406569.51             3
# 2014-01-07 21:00:00+00:00        -3161827.36     -3161827.36             4
# 2014-01-08 21:00:00+00:00        -1975367.56     -1975367.56             5
#
#                                                                 transactions  \
# 2014-01-02 21:00:00+00:00                                                 []
# 2014-01-03 21:00:00+00:00  [{'amount': -1270, 'dt': 2014-01-03 21:00:00+0...
# 2014-01-06 21:00:00+00:00  [{'amount': -1170, 'dt': 2014-01-06 21:00:00+0...
# 2014-01-07 21:00:00+00:00  [{'amount': -850, 'dt': 2014-01-07 21:00:00+00...
# 2014-01-08 21:00:00+00:00  [{'amount': -1060, 'dt': 2014-01-08 21:00:00+0...
#
#                           treasury_period_return
# 2014-01-02 21:00:00+00:00                    0.0
# 2014-01-03 21:00:00+00:00                    0.0
# 2014-01-06 21:00:00+00:00                    0.0
# 2014-01-07 21:00:00+00:00                    0.0
# 2014-01-08 21:00:00+00:00                    0.0
#
# [5 rows x 37 columns]

# %%
# %pylab inline
figsize(12, 12)
import matplotlib.pyplot as plt

ax1 = plt.subplot(211)
# ax2 = plt.subplot(211)
perf.portfolio_value.plot(ax=ax1)
# perf.benchmark_period_return.plot(ax=ax2)
ylabel('Portfolio Value')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\ogni\Anaconda3\lib\site-packages\pandas\plotting\_compat.py:57: MatplotlibDeprecationWarning:
# The compare_versions function was deprecated in Matplotlib 3.2 and will be removed two minor releases later.
#   return matplotlib.compare_versions('2.0.0', matplotlib.__version__)
# Text(0, 0.5, 'Percentage Return')

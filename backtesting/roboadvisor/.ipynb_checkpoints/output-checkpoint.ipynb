# %%
import pandas as pd
perf = pd.read_pickle('output.pickle')
perf.head()
# Out:
#                            algo_volatility  algorithm_period_return     alpha  \
# 2017-01-03 21:00:00+00:00              NaN                 0.000000       NaN
# 2017-01-04 21:00:00+00:00         0.002658                -0.000237 -0.235444
# 2017-01-05 21:00:00+00:00         0.024457                 0.002305  0.734666
# 2017-01-06 21:00:00+00:00         0.046730                 0.008410  1.555340
# 2017-01-09 21:00:00+00:00         0.074997                 0.001558 -0.186651
#
#                            benchmark_period_return  benchmark_volatility  \
# 2017-01-03 21:00:00+00:00                 0.007650                   NaN
# 2017-01-04 21:00:00+00:00                 0.013644              0.019095
# 2017-01-05 21:00:00+00:00                 0.012840              0.070894
# 2017-01-06 21:00:00+00:00                 0.016463              0.058144
# 2017-01-09 21:00:00+00:00                 0.013108              0.072752
#
#                                beta  capital_used   ending_cash  \
# 2017-01-03 21:00:00+00:00       NaN  0.000000e+00  1.000000e+07
# 2017-01-04 21:00:00+00:00  0.139183 -2.320517e+04  9.976795e+06
# 2017-01-05 21:00:00+00:00 -0.332614  3.401399e+06  1.337819e+07
# 2017-01-06 21:00:00+00:00 -0.398165 -1.010392e+06  1.236780e+07
# 2017-01-09 21:00:00+00:00  0.435679 -7.546368e+05  1.161317e+07
#
#                            ending_exposure  ending_value  \
# 2017-01-03 21:00:00+00:00            0.000         0.000
# 2017-01-04 21:00:00+00:00        20837.460     20837.460
# 2017-01-05 21:00:00+00:00     -3355145.370  -3355145.370
# 2017-01-06 21:00:00+00:00     -2283700.945  -2283700.945
# 2017-01-09 21:00:00+00:00     -1597583.090  -1597583.090
#
#                                    ...            short_exposure  short_value  \
# 2017-01-03 21:00:00+00:00          ...                     0.000        0.000
# 2017-01-04 21:00:00+00:00          ...              -2030308.220 -2030308.220
# 2017-01-05 21:00:00+00:00          ...              -4309832.320 -4309832.320
# 2017-01-06 21:00:00+00:00          ...              -3696319.345 -3696319.345
# 2017-01-09 21:00:00+00:00          ...              -3583312.440 -3583312.440
#
#                            shorts_count     sortino  starting_cash  \
# 2017-01-03 21:00:00+00:00             0         NaN   1.000000e+07
# 2017-01-04 21:00:00+00:00             2  -11.224972   1.000000e+07
# 2017-01-05 21:00:00+00:00             2   89.240320   9.976795e+06
# 2017-01-06 21:00:00+00:00             2  281.480500   1.337819e+07
# 2017-01-09 21:00:00+00:00             2    1.672703   1.236780e+07
#
#                            starting_exposure  starting_value  trading_days  \
# 2017-01-03 21:00:00+00:00              0.000           0.000             1
# 2017-01-04 21:00:00+00:00              0.000           0.000             2
# 2017-01-05 21:00:00+00:00          20837.460       20837.460             3
# 2017-01-06 21:00:00+00:00       -3355145.370    -3355145.370             4
# 2017-01-09 21:00:00+00:00       -2283700.945    -2283700.945             5
#
#                                                                 transactions  \
# 2017-01-03 21:00:00+00:00                                                 []
# 2017-01-04 21:00:00+00:00  [{'amount': -35073, 'dt': 2017-01-04 21:00:00+...
# 2017-01-05 21:00:00+00:00  [{'amount': -48461, 'dt': 2017-01-05 21:00:00+...
# 2017-01-06 21:00:00+00:00  [{'amount': -5935, 'dt': 2017-01-06 21:00:00+0...
# 2017-01-09 21:00:00+00:00  [{'amount': 10423, 'dt': 2017-01-09 21:00:00+0...
#
#                           treasury_period_return
# 2017-01-03 21:00:00+00:00                    0.0
# 2017-01-04 21:00:00+00:00                    0.0
# 2017-01-05 21:00:00+00:00                    0.0
# 2017-01-06 21:00:00+00:00                    0.0
# 2017-01-09 21:00:00+00:00                    0.0
#
# [5 rows x 37 columns]

# %%
# %pylab inline
figsize(12, 12)
import matplotlib.pyplot as plt

ax1 = plt.subplot(211)
ax2 = plt.subplot(211)
perf.algorithm_period_return.plot(ax=ax1)
perf.benchmark_period_return.plot(ax=ax1)
ylabel('Percentage Return')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\ogni\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#
# C:\Users\ogni\Anaconda3\lib\site-packages\pandas\plotting\_compat.py:57: MatplotlibDeprecationWarning:
# The compare_versions function was deprecated in Matplotlib 3.2 and will be removed two minor releases later.
#   return matplotlib.compare_versions('2.0.0', matplotlib.__version__)
# Text(0, 0.5, 'Percentage Return')
